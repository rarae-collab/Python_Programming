# %% [markdown]
# <a href="https://colab.research.google.com/github/rarae-collab/Python_Programming/blob/main/Exercise_4_(Lists)_3%EC%A3%BC%EC%B0%A8_2025195988_%EA%B9%80%EB%9D%BC%EB%9E%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Exercise 4_(Lists)_3주차_2025195988_김라래.ipynb</h1>

# %% [markdown]
# <h1>Lists in Python</h1>

# %% [markdown]
# <h3 id="index">Indexing</h3>
#
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%202/Images/ListsIndex.png" width="1000" />

# %%
# Create a list

L = ["Michael Jackson", 10.1, 1982] #[] : indexing
L
# Out:
# ['Michael Jackson', 10.1, 1982]

# %%
type(L[2])
# Out:
# int

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%202/Images/ListsNeg.png" width="1000" />

# %%
# Print the elements on each index

print('the same element using negative and positive indexing:\n Postive:',L[0],
'\n Negative:' , L[-3]  )
print('the same element using negative and positive indexing:\n Postive:',L[1],
'\n Negative:' , L[-2]  )
print('the same element using negative and positive indexing:\n Postive:',L[2],
'\n Negative:' , L[-1]  )
# Out:
# the same element using negative and positive indexing:
#  Postive: Michael Jackson
#  Negative: Michael Jackson
# the same element using negative and positive indexing:
#  Postive: 10.1
#  Negative: 10.1
# the same element using negative and positive indexing:
#  Postive: 1982
#  Negative: 1982

# %% [markdown]
# <h3 id="content">List Content</h3>

# %%
#Differnece between List and Tuple is List is mutable (changeable) but not tuple

L1 = ["Michael Jackson", 10.1, 1982, [1, 2], ("A", 1)]
print("before L1[0] changed", L1)
L1[0] = "Janet"
print("after L1[0] changed", L1)
# Out:
# before L1[0] changed ['Michael Jackson', 10.1, 1982, [1, 2], ('A', 1)]
# after L1[0] changed ['Janet', 10.1, 1982, [1, 2], ('A', 1)]

# %%
Tuple1=("Michael Jackson", 10.1, 1982)
Tuple1
Tuple1[0]="Janet"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_23990/1987079597.py in <cell line: 0>()
#       1 Tuple1=("Michael Jackson", 10.1, 1982)
#       2 Tuple1
# ----> 3 Tuple1[0]="Janet"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# <h3 id="op">List Operations (함수, 기능, 즉 LIST를 사용하면 쓸 수 있는 무기</h3>

# %%
# Sample List

L = ["Michael Jackson", 10.1,1982,"MJ",1]
L
# Out:
# ['Michael Jackson', 10.1, 1982, 'MJ', 1]

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%202/Images/ListsSlice.png" width="1000">

# %%
# List slicing

L[3:5]
# Out:
# ['MJ', 1]

# %%
# Use extend to add elements to list

L = [ "Michael Jackson", 10.2]
L.extend(['pop', 10]) #['pop', 10] --> list
L[3]
# Out:
# 10

# %%
# Use append to add elements to list

L = [ "Michael Jackson", 10.2]
L.append(['pop', 10]) #['pop', 10]
L[2][0]
# Out:
# 'pop'

# %%
# Delete the element based on the index
A = ['Michael Jackson', 10.2, 'pop', 10, ['a', 'b']]
print('Before change:', A)
del(A[0])
print('After change:', A)
# Out:
# Before change: ['Michael Jackson', 10.2, 'pop', 10, ['a', 'b']]
# After change: [10.2, 'pop', 10, ['a', 'b']]

# %%
A = ['Michael Jackson', 10.2, 'pop', 10]

# %%
# Split the string, default is by space

what='hard rock'.split()
print(what)
type(what)
what[1]
# Out:
# ['hard', 'rock']
# 'rock'

# %%
from re import split
# Split the string by comma

Split_string_comma='A,B,C,D'.split(',')
Split_string_comma
type(Split_string_comma)
Split_string_comma[0]
# Out:
# 'A'

# %% [markdown]
# <h3 id="co">Copy and Clone List</h3>

# %%
# Copy (copy by reference) the list A

A = ["hard rock", 10, 1.2]
B = A # B = A (같은 곳을 가리킨다 not equal to 같은 값을 두개 따로 가지는 것은 아니다) -->B에게 알려준다.. 너는 인제 A에서 찾아야 해...B = A (assign)


A[0] = "R&B"

print('A:', A) #R&B, 10, 1.2
print('B:', B) #'hard rock, 10, 1.2
# Out:
# A: ['R&B', 10, 1.2]
# B: ['R&B', 10, 1.2]

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%202/Images/ListsRef.png" width="1000" align="center">

# %%
# Examine the copy by reference

print('B[0]:', B[0])
A[0] = "banana"
print('B[0]:', B[0])
# Out:
# B[0]: R&B
# B[0]: banana

# %%
# Clone (clone by value) the list A
A = ["hard rock", 10, 1.2]
B = A[:] #A[:]
print(A)
print(B)
A[0] ='R&B'
print(A)
print(B)
#A[0] = "Banana"
#print(B)
#print(A)
# Out:
# ['hard rock', 10, 1.2]
# ['hard rock', 10, 1.2]
# ['R&B', 10, 1.2]
# ['hard rock', 10, 1.2]

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%202/Images/ListsVal.gif" width="1000" />

# %% [markdown]
# <h2 id="quiz">Quiz on List</h2>

# %%
#Create a list a_list, with the following elements 1, hello, [1,2,3] and True.
#The answer is below:
a_list = [1, 'hello', [1, 2, 3] , True]
a_list
# Out:
# [1, 'hello', [1, 2, 3], True]

# %%
#Find the value stored at index 1 of a_list.
#The answer is below:
a_list[1]
# Out:
# 'hello'

# %%
#Retrieve the elements stored at index 1, 2 and 3 of a_list.
#The answer is below:
a_list[1:4]
# Out:
# ['hello', [1, 2, 3], True]

# %%
#Concatenate the following lists A = [1, 'a'] and B = [2, 1, 'd']:
#The answer is below:
A = [1, 'a']
B = [2, 1, 'd']
A + B
# Out:
# [1, 'a', 2, 1, 'd']
