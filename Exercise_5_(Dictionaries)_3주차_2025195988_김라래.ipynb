# %% [markdown]
# <a href="https://colab.research.google.com/github/rarae-collab/Python_Programming/blob/main/Exercise_5_(Dictionaries)_3%EC%A3%BC%EC%B0%A8_2025195988_%EA%B9%80%EB%9D%BC%EB%9E%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Exercise_5_(Dictionaries)_3주차_2025195988_김라래</h1>

# %% [markdown]
# <h1>Dictionaries in Python</h1>

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%202/Images/DictsList.png" width="650" />

# %%
# Create the dictionary

Dict = {"key1": 1, "key2": "2", "key3": [3, 3, 3], "key4": (4, 4, 4), 'key5': 5, (0, 1): 6, 1.2: 5}
#{} :
# key1 (키값) --> 1 (정수)
# key2 (키값) --> "2" (문자열)
# key4 (키값) --> (4,4,4) tuple
# (0,1) tuple 키값 --> 5 (정수)
Dict
# Out:
# {'key1': 1,
#  'key2': '2',
#  'key3': [3, 3, 3],
#  'key4': (4, 4, 4),
#  'key5': 5,
#  (0, 1): 6,
#  1.2: 5}

# %%
# Access to the value by the key
#Dict[1.2]
#Dict['key5']
#Dict[(0,1)]
Dict["key3"]
# Out:
# [3, 3, 3]

# %%
Dict
# Out:
# {'key1': 1,
#  'key2': '2',
#  'key3': [3, 3, 3],
#  'key4': (4, 4, 4),
#  'key5': 5,
#  (0, 1): 6,
#  1.2: 5}

# %%
# Access to the value by the key

Dict["key3"]="TEST" #다른 값을 넣을 수 있는가?
Dict
# Out:
# {'key1': 1,
#  'key2': '2',
#  'key3': 'TEST',
#  'key4': (4, 4, 4),
#  'key5': 5,
#  (0, 1): 6,
#  1.2: 5}

# %%
# Create a sample dictionary

release_year_dict = {"Thriller": "1982", "Back in Black": "1980", "The Dark Side of the Moon": "1973", "The Bodyguard": "1992", \
                    "Bat Out of Hell": "1977", "Their Greatest Hits (1971-1975)": "1976", \
                    "Saturday Night Fever": "1977", "Rumours": "1977"}
release_year_dict
# Out:
# {'Thriller': '1982',
#  'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977'}

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%202/Images/DictsStructure.png" width="650" />

# %% [markdown]
# <h3 id="key">Keys</h3>

# %%
# Get value by keys

release_year_dict['Their Greatest Hits (1971-1975)']
# Out:
# '1976'

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%202/Images/DictsKeyOne.png" width="500" />

# %%
# Get value by key

release_year_dict['The Bodyguard']
# Out:
# '1992'

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%202/Images/DictsKeyTwo.png" width="500" />

# %%
# Get all the keys in dictionary

release_year_dict.keys()
# Out:
# dict_keys(['Thriller', 'Back in Black', 'The Dark Side of the Moon', 'The Bodyguard', 'Bat Out of Hell', 'Their Greatest Hits (1971-1975)', 'Saturday Night Fever', 'Rumours'])

# %%
# Get all the values in dictionary

release_year_dict.values()
# Out:
# dict_values(['1982', '1980', '1973', '1992', '1977', '1976', '1977', '1977'])

# %%
# Append value with key into dictionary

release_year_dict['Graduation'] = '2007'
release_year_dict
# Out:
# {'Thriller': '1982',
#  'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977',
#  'Graduation': '2007'}

# %%
# Delete entries by key

del(release_year_dict['Thriller'])
del(release_year_dict['Graduation'])
release_year_dict
# Out:
# {'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977'}

# %%
'Thriller' in release_year_dict
# Out:
# False

# %%
del(release_year_dict['Rumours'])

# %%
'Rumours' in release_year_dict
# Out:
# False

# %%
'The Bodyguard' in release_year_dict
# Out:
# True

# %% [markdown]
# <h2 id="quiz">Quiz on Dictionaries</h2>

# %%
# Question sample dictionary

soundtrack_dic = {"The Bodyguard":"1992", "Saturday Night Fever":"1977"}
soundtrack_dic
# Out:
# {'The Bodyguard': '1992', 'Saturday Night Fever': '1977'}

# %%
#a) In the dictionary soundtrack_dict what are the keys ?
#The answer is below:
soundtrack_dic.keys() # The Keys "The Bodyguard" and "Saturday Night Fever"
# Out:
# dict_keys(['The Bodyguard', 'Saturday Night Fever'])

# %%
#b) In the dictionary soundtrack_dict what are the values ?
#The answer is below:
soundtrack_dic.values() # The values are "1992" and "1977"
# Out:
# dict_values(['1992', '1977'])

# %%
#The Albums Back in Black, The Bodyguard and Thriller have the following music recording sales in millions 50, 50 and 65 respectively:
#a) Create a dictionary album_sales_dict where the keys are the album name and the sales in millions are the values.

#The answer is below:
album_sales_dict = {"The Bodyguard":50, "Back in Black":50, "Thriller":65}

# %%
#b) Use the dictionary to find the total sales of Thriller:
#The answer is below:
album_sales_dict["Thriller"]
# Out:
# 65

# %%
#c) Find the names of the albums from the dictionary using the method <code>keys</code>:
#The answer is below:
album_sales_dict.keys()
# Out:
# dict_keys(['The Bodyguard', 'Back in Black', 'Thriller'])

# %%
#d) Find the names of the recording sales from the dictionary using the method <code>values</code>:
#The answer is below:
album_sales_dict.values()
# Out:
# dict_values([50, 50, 65])
