# %% [markdown]
# # 13주차_scrap 01_2025195988 김라래
#
# - 이름 / 학번: 2025195988 김라래
# - 과제 내용: 강의 교안 9페이지부터의 코드를 따라서 코딩하고 실행
# - 사용 파일: `menu.xml`
# - 제출 형식: Jupyter Notebook(.ipynb)

# %% [markdown]
# ## 실행 전 준비
#
# `menu.xml` 파일이 노트북과 같은 폴더에 없으면 `FileNotFoundError`가 발생한다.
# 아래 셀은 교안 p.6의 `menu.xml` 내용을 그대로 파일로 저장하는 준비 셀이다.

# %%
xml_text = '''<?xml version="1.0"?>
<menu>
  <breakfast hours="7-11">
    <item price="$6.00">breakfast burritos</item>
    <item price="$4.00">pancakes</item>
  </breakfast>
  <lunch hours="11-3">
    <item price="$5.00">hamburger</item>
  </lunch>
  <dinner hours="3-10">
    <item price="8.00">spaghetti</item>
  </dinner>
</menu>'''

with open('menu.xml', 'w') as f:
    f.write(xml_text)

print('menu.xml 파일 생성 완료')
# Out:
# menu.xml 파일 생성 완료

# %% [markdown]
# ## 1. XML 파싱(해석)

# %%
import xml.etree.ElementTree as et
tree = et.ElementTree(file='menu.xml')
root = tree.getroot()

print(root.tag)
# Out:
# menu

# %%
type(root)
# Out:
# xml.etree.ElementTree.Element

# %% [markdown]
# ## 2. XML 내용 프린팅

# %%
for child in root:
    print('tag:', child.tag, 'attributes:', child.attrib)
    for grandchild in child:
        print('\ttag:', grandchild.tag, 'attributes:', grandchild.attrib)
# Out:
# tag: breakfast attributes: {'hours': '7-11'}
# 	tag: item attributes: {'price': '$6.00'}
# 	tag: item attributes: {'price': '$4.00'}
# tag: lunch attributes: {'hours': '11-3'}
# 	tag: item attributes: {'price': '$5.00'}
# tag: dinner attributes: {'hours': '3-10'}
# 	tag: item attributes: {'price': '8.00'}

# %% [markdown]
# ## 3. menu의 하위 태그 수와 breakfast의 item 수

# %%
len(root)
# Out:
# 3

# %%
len(root[0])
# Out:
# 2

# %%
type(root[0])
# Out:
# xml.etree.ElementTree.Element

# %% [markdown]
# ## 4. 특정 태그의 속성 값 접근

# %%
print(root[0])
print(root[0].get('hours'))
print(root[0].keys())
print(root[0].items())
# Out:
# <Element 'breakfast' at 0x10821c770>
# 7-11
# ['hours']
# [('hours', '7-11')]

# %% [markdown]
# ## 5. 태그 이름으로 찾기

# %%
lunch = root.find('lunch')
print(lunch)
print(lunch.get('hours'))
print(lunch.keys())
print(lunch.items())
# Out:
# <Element 'lunch' at 0x10821c9f0>
# 11-3
# ['hours']
# [('hours', '11-3')]

# %%
type(lunch)
# Out:
# xml.etree.ElementTree.Element

# %% [markdown]
# ## 6. 같은 이름의 태그가 여러 개일 때

# %%
print(root[0].findall('item'))
# Out:
# [<Element 'item' at 0x10821c810>, <Element 'item' at 0x10821c900>]

# %% [markdown]
# ## 7. 태그 안의 내용 프린트

# %%
print(root[0].findall('item'))

for item in root[0].findall('item'):
    print(item.get('price'))
    print(item.text)
# Out:
# [<Element 'item' at 0x10821c810>, <Element 'item' at 0x10821c900>]
# $6.00
# breakfast burritos
# $4.00
# pancakes

# %% [markdown]
# ## 8. Json dumps

# %%
import json

# %%
j1 = {"name":"홍길동", "birth":"0525", "age": 30}
j1
# Out:
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %%
json.dumps(j1)
# Out:
# '{"name": "\\ud64d\\uae38\\ub3d9", "birth": "0525", "age": 30}'

# %% [markdown]
# ## 9. Json dumps - indent 옵션

# %%
print(json.dumps(j1, indent=2))
# Out:
# {
#   "name": "\ud64d\uae38\ub3d9",
#   "birth": "0525",
#   "age": 30
# }

# %%
json.dumps([1,2,3])
# Out:
# '[1, 2, 3]'

# %%
json.dumps((4,5,6))
# Out:
# '[4, 5, 6]'

# %% [markdown]
# ## 10. Json loads

# %%
j1 = {"name":"홍길동", "birth":"0525", "age": 30}
d1 = json.dumps(j1)
json.loads(d1)
# Out:
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %% [markdown]
# ## 11. Json file

# %%
myinfo = {
    "name": "홍길동",
    "birth": "0525",
    "age": 30
}

with open('./myinfo.json', 'w') as f:
    json.dump(myinfo, f)

# %%
with open('./myinfo.json') as f:
    data = json.load(f)

print(type(data))
print(data)
# Out:
# <class 'dict'>
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %% [markdown]
# ## 12. 간단한 예제 - HTML 파일 스크래핑

# %%
from urllib.request import urlopen
import ssl

context = ssl._create_unverified_context()
html = urlopen("https://pythonscraping.com/pages/page1.html", context=context)
print(html.read())
# Out:
# b'<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %% [markdown]
# ## 13. BeautifulSoup

# %%
pip install bs4
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

context = ssl._create_unverified_context()
html = urlopen("https://pythonscraping.com/pages/page1.html", context=context)
bsObj = BeautifulSoup(html.read(), "html.parser")
print(bsObj.h1)
# Out:
# <h1>An Interesting Title</h1>

# %% [markdown]
# ## 14. BeautifulSoup 특징

# %%
bsObj.h1
# Out:
# <h1>An Interesting Title</h1>

# %%
bsObj.html.body.h1
# Out:
# <h1>An Interesting Title</h1>

# %%
bsObj.body.h1
# Out:
# <h1>An Interesting Title</h1>

# %%
bsObj.html.h1
# Out:
# <h1>An Interesting Title</h1>
