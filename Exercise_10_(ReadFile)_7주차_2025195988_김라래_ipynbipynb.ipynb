# %% [markdown]
# <a href="https://colab.research.google.com/github/rarae-collab/Python_Programming/blob/main/Exercise_10_(ReadFile)_7%EC%A3%BC%EC%B0%A8_2025195988_%EA%B9%80%EB%9D%BC%EB%9E%98_ipynbipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Reading Files Python</h1>

# %% [markdown]
# <h2 id="download">Download Data</h2>

# %%
#or use GDrive mounting method
#나의 구글드라이브에 접근할 수 있는 권한을 부여하는 것
#내가 가지고 있는 구글드라이브에서 파일 입출력을 하기 위해서

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# <h2 id="read">Reading Text Files</h2>

# %%
# Read the Example1.txt

example1 = "/content/gdrive/My Drive/Colab Notebooks/example1.txt"
file1 = open(example1, "r") #"r"는 example1 객체를 읽을 수 있는 상태로 만들자.

# %%
# Print the path of file

file1.name
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/example1.txt'

# %%
# Print the mode of file, either 'r' or 'w'

file1.mode
# Out:
# 'r'

# %%
# Read the file

FileContent = file1.read()
FileContent
# Out:
# 'This is line 1\nThis is line 2\nThis is line 3\n(empty)\nThis is line 4'

# %%
# Print the file with '\n' as a new line

print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3
# (empty)
# This is line 4

# %%
# Type of file content

type(FileContent)
# Out:
# str

# %%
# Close file after finish

file1.close()

# %% [markdown]
# <h2 id="better">A Better Way to Open a File</h2>

# %%
# Open file using with

with open(example1, "r") as file1:
    FileContent = file1.read()
    print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3
# (empty)
# This is line 4

# %%
# Verify if the file is closed

file1.closed
# Out:
# True

# %%
# See the content of file

print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3
# (empty)
# This is line 4

# %%
# Read first four characters

with open(example1, "r") as file1:
    print(file1.read(4))
# Out:
# This

# %%
# Read certain amount of characters

with open(example1, "r") as file1:
    print(file1.read(4))
    print(file1.read(4))
    print(file1.read(7))
    print(file1.read(15))
# Out:
# This
#  is
# line 1
#
# This is line 2

# %%
# Read certain amount of characters

with open(example1, "r") as file1:
    print(file1.read(16))
    print(file1.read(5))
    print(file1.read(9))
# Out:
# This is line 1
# T
# his i
# s line 2

# %%
# Read one line

with open(example1, "r") as file1:
    print("first line: " + file1.readline())
    print("second line: " + file1.readline())
    print("third line: " + file1.readline())
# Out:
# first line: This is line 1
#
# second line: This is line 2
#
# third line: This is line 3

# %%
# Iterate through the lines

with open(example1,"r") as file1:
        i = 0;
        for line in file1:
            print("Iteration", str(i), ": ", line)
            i = i + 1;
# Out:
# Iteration 0 :  This is line 1
#
# Iteration 1 :  This is line 2
#
# Iteration 2 :  This is line 3
#
# Iteration 3 :  (empty)
#
# Iteration 4 :  This is line 4

# %%
# Read all lines and save as a list --> 자주 사용함

with open(example1, "r") as file1:
    FileasList = file1.readlines()

# %%
# Print the first line

FileasList[0]
# Out:
# 'This is line 1\n'

# %%
# Print the second line

FileasList[1]
# Out:
# 'This is line 2\n'

# %%
# Print the third line

FileasList[2]
# Out:
# 'This is line 3\n'

# %%
FileasList[3]
# Out:
# '(empty)\n'

# %%
FileasList[4]
# Out:
# 'This is line 4'
