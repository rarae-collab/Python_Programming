# %% [markdown]
# <a href="https://colab.research.google.com/github/rarae-collab/Python_Programming/blob/main/Exercise_1_(Types)_Your_First_Program_2025195988_%EA%B9%80%EB%9D%BC%EB%9E%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 파이썬 프로그래밍 2주차 과제_TYPES_2025195988_김라래

# %% [markdown]
# <h2 id="hello">Exercise 1. Say "Hello" to the world in Python</h2>

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# <h2 id="hello">Exercise 1. 강의 내용 실습</h2>

# %%
# Try your first Python output

print('Hello, Python!!!!!')
print("내 이름은 김라래입니다.")
print("학번은 2025195988 입니다.")
# Out:
# Hello, Python!!!!!
# 내 이름은 김라래입니다.
# 학번은 2025195988 입니다.

# %%
# Check the Python Version

import sys #import sys (system information)
print(sys.version) #지금 사용중인 파이썬 버전
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
# Practice on writing comments
# this is just for testing

#교수님 안녕하세요. 한 학기 잘 부탁드립니다.
#초보지만 열심히 해보겠습니다. 환절기 감기 조심하시고, 즐거운 하루 보내세요! 감사합니다.
print('Hello, Python!') # This line prints a string
#print('Hi')
# Out:
# Hello, Python!

# %%
# 에러메시지 확인- Print string as error message

frint("Hello, Python!") #print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10599/773476627.py in <cell line: 0>()
#       1 # Print string as error message
#       2
# ----> 3 frint("Hello, Python!") #print
#
# NameError: name 'frint' is not defined

# %%
# 에러 수정

print("Hello, Python!") #"", ''
# Out:
# Hello, Python!

# %%
# Print string and error to see the running order - 에러 난 이후의 line은 Print 되지 않음.

print("This will be printed")
frint("This will cause an error")
print("This will NOT be printed")
# Out:
# This will be printed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10599/488948284.py in <cell line: 0>()
#       2
#       3 print("This will be printed")
# ----> 4 frint("This will cause an error")
#       5 print("This will NOT be printed")
#
# NameError: name 'frint' is not defined

# %%
print("Hello, world!") # 과제
# Out:
# Hello, world!

# %% [markdown]
# <h3 id="exercise">Exercise 2 (Types): Get the object type</h3>

# %%
type(12.0)
# Out:
# float

# %% [markdown]
# <h2 id="hello">Exercise 2.강의 내용 실습</h2>

# %%
# Integer 정수

11
# Out:
# 11

# %%
# Float 실수

2.14
# Out:
# 2.14

# %%
# String 문자열

"Hello, Python 101!"
# Out:
# 'Hello, Python 101!'

# %%
# Type of 12

type(12) #() 12 즉 12가 어떤 데이터 타입인지를 알려주는 type함수이고, 이type함수는 우리에게 12는 integer = 정수
# Out:
# int

# %%
# Type of 2.14

type(2.14) #type이라는 함수는 type( ) type의 기능은 ( )의 데이터 형태를 알려주는 함수
# Out:
# float

# %%
type(3.0) #3.0 은 실수
# Out:
# float

# %%
# Type of "Hello, Python 101!" -- type함수는 가장 마지막 라인을 읽어서 결과값을 출력함.

type(3.0) #3.0 은 실수
type("Hello, Python 101!")
# Out:
# str

# %%
type(12.0)
# Out:
# float

# %% [markdown]
# <h3 id="int">Integers</h3>

# %%
# Print the type of -1

type(-1)
# Out:
# int

# %%
# Print the type of 4

type(4)
# Out:
# int

# %%
# Print the type of 0

type(0)
# Out:
# int

# %% [markdown]
# <h3 id="float">Floats</h3>

# %%
# Print the type of 1.0

type(1.0) # Notice that 1 is an int, and 1.0 is a float
# Out:
# float

# %%
# Print the type of 0.5

type(0.5)
# Out:
# float

# %%
# Print the type of 0.56

type(0.56)
# Out:
# float

# %%
# System settings about float type

sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %% [markdown]
# <h3 id="convert">Converting from one object type to a different object type</h3>

# %%
# Verify that this is an integer

type(2)
# Out:
# int

# %%
# Convert 2 to a float
float(2)
# Out:
# 2.0

# %%
# Convert integer 2 to a float and check its type

type(float(2))
# Out:
# float

# %%
# Casting 1.1 to integer will result in loss of information

int(1.1)
# Out:
# 1

# %%
# Convert a string into an integer

int('1') #"", '' 문자열의 기호
# Out:
# 1

# %%
# Convert a string into an integer with error

int('1 or 2 people')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10599/3609426630.py in <cell line: 0>()
#       1 # Convert a string into an integer with error
#       2
# ----> 3 int('1 or 2 people')
#
# ValueError: invalid literal for int() with base 10: '1 or 2 people'

# %%
type('1.2')
# Out:
# str

# %%
# Convert the string "1.2" into a float

type(float('1.2'))
# Out:
# float

# %% [markdown]
# <h4>Converting numbers to strings</h4>

# %%
# Convert an integer to a string

str(1)
# Out:
# '1'

# %%
# Convert a float to a string

str(1.2)
# Out:
# '1.2'

# %% [markdown]
# <h3 id="bool">Boolean data type</h3>

# %%
# Value true

True
# Out:
# True

# %%
# Value false

False
# Out:
# False

# %%
# Type of True

type(True)
# Out:
# bool

# %%
# Type of False

type(False)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %% [markdown]
# <h3 id="exer_type">Exercise 3 (Types): Types</h3>

# %%
# Write your code below. Don't forget to press Shift+Enter to execute the cell

# %%
type(6/2)
# Out:
# float

# %%
# Write your code below. Don't forget to press Shift+Enter to execute the cell

# %%
type(6//2)
# Out:
# int

# %% [markdown]
# <h2 id="expressions">Expression and Variables</h2>

# %%
# Addition operation expression

43 + 60 + 16 + 41
# Out:
# 160

# %%
# Subtraction operation expression

50 - 60
# Out:
# -10

# %%
# Multiplication operation expression

5 * 5
# Out:
# 25

# %%
# Division operation expression

25 / 5
# Out:
# 5.0

# %%
# Division operation expression

25/6
# Out:
# 4.166666666666667

# %%
# Integer division operation expression

25 // 5
# Out:
# 5

# %%
# Integer division operation expression

25 // 6
# Out:
# 4

# %% [markdown]
# <h3 id="exer_exp">Exercise 4 (Types): Expression</h3>

# %%
# Write your code below. Don't forget to press Shift+Enter to execute the cell

# %%
160//60
# Out:
# 2

# %%
160/60
# Out:
# 2.6666666666666665

# %% [markdown]
# <h3 id="exer_exp">Mathematical expression</h3>

# %%
# Mathematical expression

30 + 2 * 60
# Out:
# 150

# %%
# Mathematical expression

(30 + 2) * 60
# Out:
# 1920

# %% [markdown]
# <h3 id="var">Variables (변수)</h3>

# %%
# Store value into variable

x = 43 + 60 + 16 + 41

# %%
# Print out the value in variable

x
# Out:
# 160

# %%
# Use another variable to store the result of the operation between variable and value

y =  x / 60
y
# Out:
# 2.6666666666666665

# %%
# Overwrite variable with new value

x = x / 60
x
# Out:
# 2.6666666666666665

# %%
# Name the variables meaningfully

total_min = 43 + 42 + 57 # Total length of albums in minutes
total_min
# Out:
# 142

# %%
# Name the variables meaningfully

total_hours = total_min / 60 # Total length of albums in hours
total_hours
# Out:
# 2.3666666666666667

# %%
type(total_hours)
# Out:
# float

# %%
type(total_min)
# Out:
# int

# %%
# Complicate expression

total_hours = (43 + 42 + 60) / 60  # Total hours in a single expression
total_hours
# Out:
# 2.4166666666666665

# %%
total_hours = 1000/3
total_hours
# Out:
# 333.3333333333333

# %% [markdown]
# <h3 id="exer_exp_var">Exercise 5 (Types): Expression and Variables in Python</h3>

# %%
# Write your code below. Don't forget to press Shift+Enter to execute the cell

# %%
x = 3 + 2 * 2
print(x)
# Out:
# 7

# %%
y = (3 + 2) * 2
print(y)
# Out:
# 10

# %%
x + y
# Out:
# 17
