# %% [markdown]
# <a href="https://colab.research.google.com/github/rarae-collab/Python_Programming/blob/main/Exercise_6_(Conditions)_4%EC%A3%BC%EC%B0%A8_2025195988_%EA%B9%80%EB%9D%BC%EB%9E%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Exercise_6_(Conditions)_4주차_2025195988_김라래.ipynb

# %% [markdown]
# <h1>Conditions in Python</h1>
#
# <h2 id="cond">Condition Statements</h2>

# %%
# Condition Equal

a = 5
a == 6 #a 가 6인지 확인.
# Out:
# False

# %%
# Greater than Sign

i = 6
i > 7
# Out:
# False

# %%
# Greater than Sign

i = 2
i > 5
# Out:
# False

# %%
# Inequality Sign

i = 2
i != 2 #!= not equal to...
# Out:
# False

# %%
# Inequality Sign

i = 6
i != 6
# Out:
# False

# %%
# Use Equality sign to compare the strings

"ACDC" == "Michael Jackson"
# Out:
# False

# %%
# Use Inequality sign to compare the strings

"ACDC" != "Michael Jackson"
# Out:
# True

# %% [markdown]
# <h3 id="branch">Branching</h3>

# %%
# If statement example

age = 17

#expression that can be true or false
if age > 18:
    #within an indent, we have the expression that is run if the condition is true
  print("you can enter" )
else:
  print("Prohibited")
  print("okay")

#The statements after the if statement will run regardless if the condition is true or false
#print("move on")
# Out:
# Prohibited
# okay

# %%
# Else statement example

age = 18
# age = 19

if age > 18:
  print("you can enter" )
else:
  print("go see Meat Loaf" )

print("move on")
# Out:
# go see Meat Loaf
# move on

# %%
# Elif statment example

age = 17

if age > 18:
    print("you can enter" )
elif age == 18: #else if
    print("go see Pink Floyd")
elif age == 0:
    print("this kid cannot leave home")
else:
    print("go see Meat Loaf" )

#print("move on")
# Out:
# go see Meat Loaf

# %%
# Condition statement example

album_year = 1983

if album_year > 1980:
    print("Album year is greater than 1980")

#print('do something..')
# Out:
# Album year is greater than 1980

# %%
# Condition statement example

album_year = 1983
#album_year = 1970

if album_year > 1980:
    print("Album year is greater than 1980")
else:
    print("less than 1980")

print('do something..')
# Out:
# Album year is greater than 1980
# do something..

# %%
# Condition statement example

album_year = 1991

if(album_year > 1979) and (album_year < 1990):
    print ("Album year was in between 1980 and 1989")
else:
    print("this is not the case")
# Out:
# this is not the case

# %%
# Condition statement example

album_year = 1980

if(album_year < 1980) or (album_year > 1989):
    print ("Album was not made in the 1980's")
else:
    print("The Album was made in the 1980's ")
# Out:
# The Album was made in the 1980's

# %%
# Condition statement example

album_year = 1983

if not (album_year == '1984'):
    print ("Album year is not 1984")
# Out:
# Album year is not 1984

# %% [markdown]
# <h2 id="quiz">Quiz on Conditions</h2>

# %%
#Write an if statement to determine if an album had a rating greater than 8.
#Test it using the rating for the album “Back in Black” that had a rating of 8.5.
#If the statement is true print "This album is Amazing!"
#The answer is below:
rating = 8.5
if rating > 8:
    print ("This album is Amazing!")
# Out:
# This album is Amazing!

# %%
#Write an if-else statement that performs the following.
#If the rating is larger then eight print “this album is amazing”.
#If the rating is less than or equal to 8 print “this album is ok”.
#The answer is below:
rating = 8.5
if rating > 8:
    print ("this album is amazing")
else:
    print ("this album is ok")
# Out:
# this album is amazing

# %%
#Write an if statement to determine if an album came out before 1980 or in the years: 1991 or 1993.
#If the condition is true print out the year the album came out.
#The answer is below:
album_year = 1979

if album_year < 1980 or album_year == 1991 or album_year == 1993:
    print ("this album came out already")
# Out:
# this album came out already
